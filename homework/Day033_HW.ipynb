# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get(' https://github.com/new', verify = False)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text)
# Out:
# /Users/hsiyu/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/hsiyu/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# Sign in to GitHub · GitHub
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sign in to GitHub
#
#
#
#
#
#           Username or email address
#
#
#
#           Password Forgot password?
#
#
#
#
#
#
#
#
#
#
#
#         New to GitHub?
# ...

# %%
cookies={'Cookie': '_octo=GH1.1.2083968233.1577978089; \
         _ga=GA1.2.884097968.1577978090; tz=Asia%2FTaipei; \
         _device_id=7dab33e37a19fa78a9fcd2f0350a5957; ignored_unsupported_browser_notice=false; \
         has_recent_activity=1; user_session=sH0Iu8zAlwEcOadHhup5b7kbGxoH9NsVkpKtG7qcASwa4Xv6; \
         __Host-user_session_same_site=sH0Iu8zAlwEcOadHhup5b7kbGxoH9NsVkpKtG7qcASwa4Xv6; \
         logged_in=yes; dotcom_user=hsiyu1121; _gat=1; \
         _gh_sess=cktlZWc4WGNQemV6Y082U05XamNGendlRTlIMTczbU9RQXc5eTExcFhOTTl6RGFLK2lISnNrd \
         21SR1QvelRFalN6VHY0L0FrcVB5dHlQdGkzbm56NDhOQ3RWT1dVc0lTbUtCU0tPVE1WOHJaRkVPTXVSVEcxR \
         FZLRmplSU9IK0Z0S2xjOFRZQlRDb3VnakQ4OWwzbW9ydmZ5R2pmYTFQV1VWSjNnS2lSVE9URXRCWmpqYUkxbmcr \
         Y0QxTHZNZyszSFJST1BsNktGc0V6MFB1ZDdLbDMwUzZVSTRRVzJiMmRRZ21QODNkWWlNTjEvajVoQWtYU0poaUVaOV \
         k3VDg5dFFUM3ZvNU81dWlCSThsRVNrbFpINlA3SjhQWS96Z1ordUg0N2duUXVqY2U3cXYvMTJhMy9ZUVpjZ \
         zkwYTVYa0Y4aDl1QXhlR1NyYVhMamNFS1VmOG0wQ2NxSXV0TFR6Tkw1NWRrbzlnWVgvdUdVUjEyVklISkFWZXF \
         PWG5XMW1iMFVkc3lad2Rvb1dqTzN5UCs5TG8zbDdLUDVCd1JGMWlUSUpoZEFyZU1seWhlWVZjNUJCK1UvN3FFTC \
         tRTFVXRys5eXZ6M0FzMFk4VXo3QmU4S3RqZFFMVXBtc1FrOUxRUVRJTzFZckMwNDNZNXBwdXk2NDlsMFV6ckFk \
         cVZ6aVkrYS9XYXYwc1VMQUtvcEVoclp6UFh1Yzl4eHM0Tk5Qdlp5cEh2RWx3MkJMdGdXL0Z2TStzYVhIREFzeW5 \
         qY2VZU2Q3cXYyVVUyN1Rjam1ndnJrejRSS2lIYTl0ZmtLSXA5S3k5THhOMDRVN3RYQ002cGpxNUU0Z215N3hmUG \
         gyOTU3dFlyUWU2YkxoVzBWT1lRdXVqY1RneDJaejlYNVBybWlxVnE3WGVrb25zV2w2bUdCbkFsOTRWTzlEbWx1V \
         UdXUnh2RU5ZY0JwU1gzSHpGRFpDbVRDSkcvY2o2UHZLOEtLajZmVGFVNStvc2VhUmNKY3ZvMDlLZGtMb0FrQ284b \
         GVKQTVNelBwbHlQZ1o4MEFSSDBiRHFHcmNKajNhQnRuS0J3cHE1T0ViSlVHYTdDZ25xbkEzQzI3YW91ZGwzL0hHe \
         kx2K09xd3BxWXpsa2p2L2FCMXYyZnYxMGc2Nk9FK04wRVNxWkVmQ20vdUlhTVByK2wyamFKSlFYU1NmWlY3MTEvU \
         EVWeGdWY0o3SHRLejRBOTNWY2dJSk14WkY3bklwaEsrMHJidzFZMDB3YTNmYlpqamx4Rmdzaml4ejhTN21KblFiY1 \
         o5N3VHeDB4NjI5TWN2K2RhUkVqUSsvc2NYL1Vxb2RPM1BzSjZWcjdPc1pIZkVEMXQ4MmpWWXA4ZFp0dGFWZ1J1SFl \
         nbmVlMmk0VVdzMC9zOWs2MHNiYlVsdEVmRmxzL0RHUzdxOTFiVDZ5LzlCNEFRUzBjSk4zRE9KTUlvYWN0VXd2aFpR \
         TlBHYXAzZ2ZBdnlDYXIwdHdPWkM0RXl3YzBYOHdRMktuSFZ5OG4wNmoyYklNRzc0VThycDZRV2hHRWZTWXI0QS9qZ \
         i9lMk1RVjNTMEd1Tm45YmNwNWxPYnRGVHNlZz0tLWpTVkNxYndvdmhvTFNuZmZXUnpCMEE9PQ%3D%3D--ba091dd1 \
         4146c3e13c364bcec57a9e7453637471'}


res = requests.get(' https://github.com/new', verify = False, cookies=cookies )
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text)
# Out:
# /Users/hsiyu/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# Create a New Repository
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search
#
#
#         All GitHub
#
# ↵
#
#
#       Jump to
#       ↵
#
#
#
#
#
#
# No suggested jump to results
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search
#
#
#         All GitHub
#
# ↵
#
#
#       Jump to
#       ↵
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search
#
#
#         All GitHub
#
# ↵
#
#
#       Jump to
#       ↵
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Pull requests
#
#
#     Issues
#
#
#
#         Marketplace
#
#
#
#     Explore
#
#
#
#
#
#
#
#
# ...
